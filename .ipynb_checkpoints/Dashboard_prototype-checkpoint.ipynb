# %%
import panel as pn

pn.extension()

def power_setting_bar(power_setting):
    return power_setting

pn.interact(power_setting_bar, power_setting = 10)
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>
# Column
#     [0] Column
#         [0] IntSlider(end=30, name='power_setting', start=-10, value=10)
#     [1] Row
#         [0] Str(int, name='interactive00101')

# %%
import panel as pn
pn.extension()
power = pn.widgets.IntSlider(name='Power Setting', width=250, start=0, end=33)
power
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>
# IntSlider(end=33, name='Power Setting', width=250)

# %%
w1 = pn.widgets.TextInput(name='Power Setting:')
w2 = pn.widgets.FloatSlider(name='Slider')

row = pn.Row('### Row', w1, background='WhiteSmoke')
row

mylink = link((w, 'value'), (b, 'value'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [3], line 7
#       4 row = pn.Row('### Row', w1, background='WhiteSmoke')
#       5 row
# ----> 7 mylink = link((w, 'value'), (b, 'value'))
#
# NameError: name 'link' is not defined

# %%
pn.Row(
    pn.Spacer(background='red',   sizing_mode='stretch_both'),
    pn.Spacer(background='green', sizing_mode='stretch_both'),
    pn.Spacer(background='blue',  sizing_mode='stretch_both'),
    height=100, width=400
)
# Out:
# Row(height=100, sizing_mode='fixed', width=400)
#     [0] Spacer(background='red', sizing_mode='stretch_both')
#     [1] Spacer(background='green', sizing_mode='stretch_both')
#     [2] Spacer(background='blue', sizing_mode='stretch_both')

# %%
import ipywidgets as widgets

a = widgets.FloatText(name = 'Power Settings')
b = widgets.FloatSlider(min = 0, max = 33, step = 0.5, value = 33)
# display(a,b)

mylink = widgets.jslink((a,'value'), (b,'value'))
row1 = pn.Row( a, background='WhiteSmoke')
row2 = pn.Row(b, background='WhiteSmoke')
display(row1,row2)
# Out:
# Row(background='WhiteSmoke')
#     [0] IPyWidget(FloatText)
# Row(background='WhiteSmoke')
#     [0] IPyWidget(FloatSlider)

# %%
import ipywidgets as widgets

widgets.IntSlider()
from IPython.display import display
w = widgets.IntSlider()
uploader = widgets.FileUpload(
    accept='*.csv',  # Accepted file extension e.g. '.txt', '.pdf', 'image/*', 'image/*,.pdf'
    multiple=False  # True to accept multiple files upload else False
)
display(uploader)
# Out:
# FileUpload(value=(), accept='*.csv', description='Upload')

# %%
import io
import pandas as pd
print(type(uploader))
# Out:
# <class 'ipywidgets.widgets.widget_upload.FileUpload'>

# %%
import os
os.getcwd()
inventory_cycle_csv = pd.read_csv('Inventory_Cycle.csv')

# %%
inventory_cycle_csv
# Out:
#          Current Time                 EPC Value         Count
# 0            14:03:09                  F00012F8  [2, 0, 0, 0]
# 1            14:03:16              A00000000099  [4, 0, 0, 0]
# 2            14:03:16              A00000000088  [3, 0, 0, 0]
# 3            14:03:16              A00000000044  [4, 0, 0, 0]
# 4            14:03:16          BCD5000000000008  [1, 0, 0, 0]
# 5            14:03:16              A00000000023  [4, 0, 0, 0]
# 6            14:03:16  30363A6C7026E9AA6D3CB8E2  [1, 0, 0, 0]
# 7            14:03:16              A00000000053  [3, 0, 0, 0]
# 8            14:03:16          BCD5000000000005  [2, 0, 0, 0]
# 9            14:03:16  E2801191A50300620A26D220  [2, 0, 0, 0]
# 10           14:03:16              A00000000093  [4, 0, 0, 0]
# 11           14:03:16              BCD500000777  [4, 0, 0, 0]
# 12           14:03:16                  F0001327  [2, 0, 0, 0]
# 13           14:03:16                  F00012A7  [2, 0, 0, 0]
# ...

# %% [markdown]
# # Creating Dashboard
